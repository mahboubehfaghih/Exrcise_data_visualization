# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html).
#
# The dataset being used is *Tips* from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Magic matplotlib command to have plots shown in the notebook
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
url="https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv "

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips= pd.read_csv(url)
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 4. Delete the `Unnamed: 0` column

# %%
del tips["Unnamed: 0"]

# %% [markdown]
# ### Step 5. Create a histogram with the `total_bill` column.

# %%
#creat histogram
a= sns.distplot(tips.total_bill)

#set labels and title
a.set(xlabel="Value", ylabel="Freqency", title="Total bill")

# take out the right and upper borders
sns.despine()
# Out:
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 6. Create a scatter plot representing the relationship between `total_bill` and `tip`, while also showing the distribution of each variable as a histogram.
# Hint: It's just a single function call.

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# give you more information

sns.jointplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# ### Step 7.  Display the relationship between all the numerical variables using a single plot.
# Hint: It's just a single function call.

# %%
#Display the relationship between "total_bill", "tip" and "size" using a single plot.

sns.pairplot(tips)

# %%
#another way

#Display the relationship between "total_bill", "tip" and "size" using a single plot.

sns.scatterplot(x="total_bill", 
                y="tip", 
                data=tips,
                size="size"
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Step 8. Create a scatter plot with the categorical variable `day` and it's relation to `total_bill`.

# %%
sns.stripplot(x="day",y="total_bill", data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="total_bill", y="day", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the categorical variable `day` and it's relation to `tip`. Put the `day` on the y-axis. Differentiate the dots by sex.

# %%
sns.stripplot(x="tip", 
            y="day", 
            hue="sex",
            data=tips,
            jitter=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
# an other way
sns.scatterplot(x="tip", 
                y="day", 
                hue="sex",
                data=tips
  )
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
#five you more information

sns.swarmplot(x="tip", 
                y="day", 
                hue="sex",
                data=tips
  )
# Out:
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot representing the `total_bill` per `day`, while also differentiating by `time` (Dinner or Lunch).

# %%
sns.boxplot(y="total_bill", x="day", hue="time", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="total_bill", y="day", hue="time", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### Step 11. Create two histograms of `tip`, based on whether it is dinner time or lunch time. They must be side by side.

# %%
g=sns.FacetGrid(tips, col="time")
g.map(sns.distplot, "tip")
# Out:
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#beter seaborn style
sns.set(style="ticks")
#creat FacetGrid
g=sns.FacetGrid(tips, col="time")
g.map(plt.hist, "tip")

# %% [markdown]
# ### Step 12. Create two scatter plots, one for male and another for female, representing the `total_bill` and `tip` relationship, differentiating by smoker or no smoker.
# ### They must be side by side.

# %%
g=sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(plt.scatter, "total_bill", "tip", alpha=0.7)

g.add_legend();

# %%
#an other way

g=sns.FacetGrid(tips, col="sex")
g.map_dataframe(sns.scatterplot, x="tip", y="total_bill", hue="smoker")

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
# https://www.youtube.com/watch?v=oiuKFigW4YM
